# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# open np files
def load_data(file_path):
    general_file_path = '../../../data/newModel/test_results'
    file_path = os.path.join(general_file_path, file_path)
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File {file_path} does not exist.")
    data = np.load(file_path, allow_pickle=True)
    return data

# %%
ETTh2_24_true_path_i = 'Finetune_ETTh2_UTSD-1G_INTREPETER_24_Exp25-06-15_14-20-53/ETTh2.csv/1440/true_0_0.npy'
print(f"Loading data from {ETTh2_24_true_path_i}")
ETTh2_24_true_data_i= load_data(ETTh2_24_true_path_i)
ETTh2_24_true_mean_i = np.mean(ETTh2_24_true_data_i, axis=0)
ETTh2_24_true_std_i = np.std(ETTh2_24_true_data_i, axis=0)
ETTh2_24_true_data_normalized_i = (ETTh2_24_true_data_i - ETTh2_24_true_mean_i) / ETTh2_24_true_std_i

ETTh2_24_pred_path_i = 'Finetune_ETTh2_UTSD-1G_INTREPETER_24_Exp25-06-15_14-20-53/ETTh2.csv/1440/pred_0_0.npy'
print(f"Loading data from {ETTh2_24_pred_path_i}")
ETTh2_24_pred_data_i= load_data(ETTh2_24_pred_path_i)
ETTh2_24_pred_mean_i = np.mean(ETTh2_24_pred_data_i, axis=0)
ETTh2_24_pred_std_i = np.std(ETTh2_24_pred_data_i, axis=0)
ETTh2_24_pred_data_normalized_i = (ETTh2_24_pred_data_i - ETTh2_24_pred_mean_i) / ETTh2_24_pred_std_i

ETTh2_24_enc_out_path_i = 'Finetune_ETTh2_UTSD-1G_INTREPETER_24_Exp25-06-15_14-20-53/ETTh2.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {ETTh2_24_enc_out_path_i}")
ETTh2_24_enc_out_data_i = load_data(ETTh2_24_enc_out_path_i)
ETTh2_24_enc_out_mean_i = np.mean(ETTh2_24_enc_out_data_i, axis=0)
ETTh2_24_enc_out_std_i = np.std(ETTh2_24_enc_out_data_i, axis=0)
ETTh2_24_enc_out_data_normalized_i = (ETTh2_24_enc_out_data_i - ETTh2_24_enc_out_mean_i) / ETTh2_24_enc_out_std_i

ETTh2_residual_i = ETTh2_24_pred_data_normalized_i - ETTh2_24_enc_out_data_normalized_i


TRC_24_true_path_i = 'Finetune_TRC_UTSD-1G_INTREPETER_24_Exp25-06-15_14-24-01/TRC.csv/1440/true_0_0.npy'
print(f"Loading data from {TRC_24_true_path_i}")
TRC_24_true_data_i = load_data(TRC_24_true_path_i)
TRC_24_true_mean_i = np.mean(TRC_24_true_data_i, axis=0)
TRC_24_true_std_i = np.std(TRC_24_true_data_i, axis=0)
TRC_24_true_data_normalized_i = (TRC_24_true_data_i - TRC_24_true_mean_i) / TRC_24_true_std_i

TRC_24_pred_path_i = 'Finetune_TRC_UTSD-1G_INTREPETER_24_Exp25-06-15_14-24-01/TRC.csv/1440/pred_0_0.npy'
print(f"Loading data from {TRC_24_pred_path_i}")
TRC_24_pred_data_i = load_data(TRC_24_pred_path_i)
TRC_24_pred_mean_i = np.mean(TRC_24_pred_data_i, axis=0)
TRC_24_pred_std_i = np.std(TRC_24_pred_data_i, axis=0)
TRC_24_pred_data_normalized_i = (TRC_24_pred_data_i - TRC_24_pred_mean_i) / TRC_24_pred_std_i

TRC_24_enc_out_path_i = 'Finetune_TRC_UTSD-1G_INTREPETER_24_Exp25-06-15_14-24-01/TRC.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {TRC_24_enc_out_path_i}")
TRC_24_enc_out_data_i = load_data(TRC_24_enc_out_path_i)
TRC_24_enc_out_mean_i = np.mean(TRC_24_enc_out_data_i, axis=0)
TRC_24_enc_out_std_i = np.std(TRC_24_enc_out_data_i, axis=0)
TRC_24_enc_out_data_normalized_i = (TRC_24_enc_out_data_i - TRC_24_enc_out_mean_i) / TRC_24_enc_out_std_i

TRC_residual_i = TRC_24_pred_data_normalized_i - TRC_24_enc_out_data_normalized_i


WTH_24_true_path_i = 'Finetune_WTH_UTSD-1G_INTREPETER_24_Exp25-06-15_14-22-37/WTH.csv/1440/true_0_0.npy'
print(f"Loading data from {WTH_24_true_path_i}")
WTH_24_true_data_i = load_data(WTH_24_true_path_i)
WTH_24_true_mean_i = np.mean(WTH_24_true_data_i, axis=0)
WTH_24_true_std_i = np.std(WTH_24_true_data_i, axis=0)
WTH_24_true_data_normalized_i = (WTH_24_true_data_i - WTH_24_true_mean_i) / WTH_24_true_std_i

WTH_24_pred_path_i = 'Finetune_WTH_UTSD-1G_INTREPETER_24_Exp25-06-15_14-22-37/WTH.csv/1440/pred_0_0.npy'
print(f"Loading data from {WTH_24_pred_path_i}")
WTH_24_pred_data_i = load_data(WTH_24_pred_path_i)
WTH_24_pred_mean_i = np.mean(WTH_24_pred_data_i, axis=0)
WTH_24_pred_std_i = np.std(WTH_24_pred_data_i, axis=0)
WTH_24_pred_data_normalized_i = (WTH_24_pred_data_i - WTH_24_pred_mean_i) / WTH_24_pred_std_i

WTH_24_enc_out_path_i = 'Finetune_WTH_UTSD-1G_INTREPETER_24_Exp25-06-15_14-22-37/WTH.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {WTH_24_enc_out_path_i}")
WTH_24_enc_out_data_i = load_data(WTH_24_enc_out_path_i)
WTH_24_enc_out_mean_i = np.mean(WTH_24_enc_out_data_i, axis=0)
WTH_24_enc_out_std_i = np.std(WTH_24_enc_out_data_i, axis=0)
WTH_24_enc_out_data_normalized_i = (WTH_24_enc_out_data_i - WTH_24_enc_out_mean_i) / WTH_24_enc_out_std_i

WTH_residual_i = WTH_24_pred_data_normalized_i - WTH_24_enc_out_data_normalized_i


ECL_24_enc_out_path_i = 'Finetune_ECL_UTSD-1G_INTREPETER_24_Exp25-06-16_09-07-48/ECL.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {ECL_24_enc_out_path_i}")
ECL_24_enc_out_data_i = load_data(ECL_24_enc_out_path_i)
ECL_24_enc_out_mean_i = np.mean(ECL_24_enc_out_data_i, axis=0)
ECL_24_enc_out_std_i = np.std(ECL_24_enc_out_data_i, axis=0)
ECL_24_enc_out_data_normalized_i = (ECL_24_enc_out_data_i - ECL_24_enc_out_mean_i) / ECL_24_enc_out_std_i
ECL_24_pred_path_i = 'Finetune_ECL_UTSD-1G_INTREPETER_24_Exp25-06-16_09-07-48/ECL.csv/1440/pred_0_0.npy'
print(f"Loading data from {ECL_24_pred_path_i}")
ECL_24_pred_data_i = load_data(ECL_24_pred_path_i)
ECL_24_pred_mean_i = np.mean(ECL_24_pred_data_i, axis=0)
ECL_24_pred_std_i = np.std(ECL_24_pred_data_i, axis=0)
ECL_24_pred_data_normalized_i = (ECL_24_pred_data_i - ECL_24_pred_mean_i) / ECL_24_pred_std_i
ECL_residual_i = ECL_24_pred_data_normalized_i - ECL_24_enc_out_data_normalized_i
# Out:
# Loading data from Finetune_ETTh2_UTSD-1G_INTREPETER_24_Exp25-06-15_14-20-53/ETTh2.csv/1440/true_0_0.npy
# Loading data from Finetune_ETTh2_UTSD-1G_INTREPETER_24_Exp25-06-15_14-20-53/ETTh2.csv/1440/pred_0_0.npy
# Loading data from Finetune_ETTh2_UTSD-1G_INTREPETER_24_Exp25-06-15_14-20-53/ETTh2.csv/1440/enc_out_0_0.npy
# Loading data from Finetune_TRC_UTSD-1G_INTREPETER_24_Exp25-06-15_14-24-01/TRC.csv/1440/true_0_0.npy
# Loading data from Finetune_TRC_UTSD-1G_INTREPETER_24_Exp25-06-15_14-24-01/TRC.csv/1440/pred_0_0.npy
# Loading data from Finetune_TRC_UTSD-1G_INTREPETER_24_Exp25-06-15_14-24-01/TRC.csv/1440/enc_out_0_0.npy
# Loading data from Finetune_WTH_UTSD-1G_INTREPETER_24_Exp25-06-15_14-22-37/WTH.csv/1440/true_0_0.npy
# Loading data from Finetune_WTH_UTSD-1G_INTREPETER_24_Exp25-06-15_14-22-37/WTH.csv/1440/pred_0_0.npy
# Loading data from Finetune_WTH_UTSD-1G_INTREPETER_24_Exp25-06-15_14-22-37/WTH.csv/1440/enc_out_0_0.npy
# ...

# %%
ETTh2_24_true_path_g = 'Finetune_ETTh2_UTSD-1G_GENERIC_24_Exp25-06-15_14-37-37/ETTh2.csv/1440/true_0_0.npy'
print(f"Loading data from {ETTh2_24_true_path_g}")
ETTh2_24_true_data_g= load_data(ETTh2_24_true_path_g)
ETTh2_24_true_mean_g = np.mean(ETTh2_24_true_data_g, axis=0)
ETTh2_24_true_std_g = np.std(ETTh2_24_true_data_g, axis=0)
ETTh2_24_true_data_normalized_g = (ETTh2_24_true_data_g - ETTh2_24_true_mean_g) / ETTh2_24_true_std_g

ETTh2_24_pred_path_g = 'Finetune_ETTh2_UTSD-1G_GENERIC_24_Exp25-06-15_14-37-37/ETTh2.csv/1440/pred_0_0.npy'
print(f"Loading data from {ETTh2_24_pred_path_g}")
ETTh2_24_pred_data_g= load_data(ETTh2_24_pred_path_g)
ETTh2_24_pred_mean_g = np.mean(ETTh2_24_pred_data_g, axis=0)
ETTh2_24_pred_std_g = np.std(ETTh2_24_pred_data_g, axis=0)
ETTh2_24_pred_data_normalized_g = (ETTh2_24_pred_data_g - ETTh2_24_pred_mean_g) / ETTh2_24_pred_std_g

ETTh2_24_enc_out_path_g = 'Finetune_ETTh2_UTSD-1G_GENERIC_24_Exp25-06-15_14-37-37/ETTh2.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {ETTh2_24_enc_out_path_g}")
ETTh2_24_enc_out_data_g= load_data(ETTh2_24_enc_out_path_g)
ETTh2_24_enc_out_mean_g = np.mean(ETTh2_24_enc_out_data_g, axis=0)
ETTh2_24_enc_out_std_g = np.std(ETTh2_24_enc_out_data_g, axis=0)
ETTh2_24_enc_out_data_normalized_g = (ETTh2_24_enc_out_data_g - ETTh2_24_enc_out_mean_g) / ETTh2_24_enc_out_std_g

ETTh2_residual_g = ETTh2_24_pred_data_normalized_g - ETTh2_24_enc_out_data_normalized_g


ECL_24_true_path_g = 'Finetune_ECL_UTSD-1G_GENERIC_24_Exp25-06-15_14-44-29/ECL.csv/1440/true_0_0.npy'
print(f"Loading data from {ECL_24_true_path_g}")
ECL_24_true_data_g = load_data(ECL_24_true_path_g)
ECL_24_true_mean_g = np.mean(ECL_24_true_data_g, axis=0)
ECL_24_true_std_g = np.std(ECL_24_true_data_g, axis=0)
ECL_24_true_data_normalized_g = (ECL_24_true_data_g - ECL_24_true_mean_g) / ECL_24_true_std_g

ECL_24_pred_path_g = 'Finetune_ECL_UTSD-1G_GENERIC_24_Exp25-06-15_14-44-29/ECL.csv/1440/pred_0_0.npy'
print(f"Loading data from {ECL_24_pred_path_g}")
ECL_24_pred_data_g = load_data(ECL_24_pred_path_g)
ECL_24_pred_mean_g = np.mean(ECL_24_pred_data_g, axis=0)
ECL_24_pred_std_g = np.std(ECL_24_pred_data_g, axis=0)
ECL_24_pred_data_normalized_g = (ECL_24_pred_data_g - ECL_24_pred_mean_g) / ECL_24_pred_std_g

ECL_24_enc_out_path_g = 'Finetune_ECL_UTSD-1G_GENERIC_24_Exp25-06-15_14-44-29/ECL.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {ECL_24_enc_out_path_g}")
ECL_24_enc_out_data_g = load_data(ECL_24_enc_out_path_g)
ECL_24_enc_out_mean_g = np.mean(ECL_24_enc_out_data_g, axis=0)
ECL_24_enc_out_std_g = np.std(ECL_24_enc_out_data_g, axis=0)
ECL_24_enc_out_data_normalized_g = (ECL_24_enc_out_data_g - ECL_24_enc_out_mean_g) / ECL_24_enc_out_std_g

ECL_residual = ECL_24_pred_data_normalized_g - ECL_24_enc_out_data_normalized_g


TRC_24_true_path_g = 'Finetune_TRC_UTSD-1G_GENERIC_24_Exp25-06-15_14-40-15/TRC.csv/1440/true_0_0.npy'
print(f"Loading data from {TRC_24_true_path_g}")
TRC_24_true_data_g = load_data(TRC_24_true_path_g)
TRC_24_true_mean_g = np.mean(TRC_24_true_data_g, axis=0)
TRC_24_true_std_g = np.std(TRC_24_true_data_g, axis=0)
TRC_24_true_data_normalized_g = (TRC_24_true_data_g - TRC_24_true_mean_g) / TRC_24_true_std_g

TRC_24_pred_path_g = 'Finetune_TRC_UTSD-1G_GENERIC_24_Exp25-06-15_14-40-15/TRC.csv/1440/pred_0_0.npy'
print(f"Loading data from {TRC_24_pred_path_g}")
TRC_24_pred_data_g = load_data(TRC_24_pred_path_g)
TRC_24_pred_mean_g = np.mean(TRC_24_pred_data_g, axis=0)
TRC_24_pred_std_g = np.std(TRC_24_pred_data_g, axis=0)
TRC_24_pred_data_normalized_g = (TRC_24_pred_data_g - TRC_24_pred_mean_g) / TRC_24_pred_std_g

TRC_24_enc_out_path_g = 'Finetune_TRC_UTSD-1G_GENERIC_24_Exp25-06-15_14-40-15/TRC.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {TRC_24_enc_out_path_g}")
TRC_24_enc_out_data_g = load_data(TRC_24_enc_out_path_g)
TRC_24_enc_out_mean_g = np.mean(TRC_24_enc_out_data_g, axis=0)
TRC_24_enc_out_std_g = np.std(TRC_24_enc_out_data_g, axis=0)
TRC_24_enc_out_data_normalized_g = (TRC_24_enc_out_data_g - TRC_24_enc_out_mean_g) / TRC_24_enc_out_std_g
TRC_residual_g = TRC_24_pred_data_normalized_g - TRC_24_enc_out_data_normalized_g


WTH_24_true_path_g = 'Finetune_WTH_UTSD-1G_GENERIC_24_Exp25-06-15_14-39-06/WTH.csv/1440/true_0_0.npy'
print(f"Loading data from {WTH_24_true_path_g}")
WTH_24_true_data_g = load_data(WTH_24_true_path_g)
WTH_24_true_mean_g = np.mean(WTH_24_true_data_g, axis=0)
WTH_24_true_std_g = np.std(WTH_24_true_data_g, axis=0)
WTH_24_true_data_normalized_g = (WTH_24_true_data_g - WTH_24_true_mean_g) / WTH_24_true_std_g

WTH_24_pred_path_g = 'Finetune_WTH_UTSD-1G_GENERIC_24_Exp25-06-15_14-39-06/WTH.csv/1440/pred_0_0.npy'
print(f"Loading data from {WTH_24_pred_path_g}")
WTH_24_pred_data_g = load_data(WTH_24_pred_path_g)
WTH_24_pred_mean_g = np.mean(WTH_24_pred_data_g, axis=0)
WTH_24_pred_std_g = np.std(WTH_24_pred_data_g, axis=0)
WTH_24_pred_data_normalized_g = (WTH_24_pred_data_g - WTH_24_pred_mean_g) / WTH_24_pred_std_g

WTH_24_enc_out_path_g = 'Finetune_WTH_UTSD-1G_GENERIC_24_Exp25-06-15_14-39-06/WTH.csv/1440/enc_out_0_0.npy'
print(f"Loading data from {WTH_24_enc_out_path_g}")
WTH_24_enc_out_data_g = load_data(WTH_24_enc_out_path_g)
WTH_24_enc_out_mean_g = np.mean(WTH_24_enc_out_data_g, axis=0)
WTH_24_enc_out_std_g = np.std(WTH_24_enc_out_data_g, axis=0)
WTH_24_enc_out_data_normalized_g = (WTH_24_enc_out_data_g - WTH_24_enc_out_mean_g) / WTH_24_enc_out_std_g
WTH_residual_g = WTH_24_pred_data_normalized_g - WTH_24_enc_out_data_normalized_g
# Out:
# Loading data from Finetune_ETTh2_UTSD-1G_GENERIC_24_Exp25-06-15_14-37-37/ETTh2.csv/1440/true_0_0.npy
# Loading data from Finetune_ETTh2_UTSD-1G_GENERIC_24_Exp25-06-15_14-37-37/ETTh2.csv/1440/pred_0_0.npy
# Loading data from Finetune_ETTh2_UTSD-1G_GENERIC_24_Exp25-06-15_14-37-37/ETTh2.csv/1440/enc_out_0_0.npy
# Loading data from Finetune_ECL_UTSD-1G_GENERIC_24_Exp25-06-15_14-44-29/ECL.csv/1440/true_0_0.npy
# Loading data from Finetune_ECL_UTSD-1G_GENERIC_24_Exp25-06-15_14-44-29/ECL.csv/1440/pred_0_0.npy
# Loading data from Finetune_ECL_UTSD-1G_GENERIC_24_Exp25-06-15_14-44-29/ECL.csv/1440/enc_out_0_0.npy
# Loading data from Finetune_TRC_UTSD-1G_GENERIC_24_Exp25-06-15_14-40-15/TRC.csv/1440/true_0_0.npy
# Loading data from Finetune_TRC_UTSD-1G_GENERIC_24_Exp25-06-15_14-40-15/TRC.csv/1440/pred_0_0.npy
# Loading data from Finetune_TRC_UTSD-1G_GENERIC_24_Exp25-06-15_14-40-15/TRC.csv/1440/enc_out_0_0.npy
# ...

# %%
#Combine ETTh2
plt.figure(figsize=(5, 5))
plt.plot(ETTh2_24_true_data_g[0:50, 0], label='True Value', color='red')
plt.plot(ETTh2_24_pred_data_g[0:50, 0], label='MLP Output', color='blue')
plt.plot(ETTh2_24_pred_data_i[0:50, 0], label='Interpreter Output', color='green')

plt.xlabel('Time Steps')
plt.ylabel('Output Value')
plt.legend()
plt.grid()
plt.tight_layout()
# Show the plot
plt.show()
# Close the plot to free up memory
plt.close()
# Print a message indicating successful completion
print("Plotting completed successfully.")
# Out:
# Plotting completed successfully.

# %%
colors_academic = {
    'primary': '#0C5DA5',    # 深蓝（主色）
    'secondary': '#00B945',  # 青绿（次色）
    'accent': '#FF9500',     # 橙黄（强调色）
    'neutral': '#474747',    # 中灰（中性色）
    'background': '#FFFFFF',  # 白色背景
    'critical_alert': '#D62728',    # 火砖红（错误/异常值）[1,6](@ref)
    'highlight': '#FFD700',        # 亮金色（关键结论）[3](@ref)
    'attention': '#FF9800',        # 活力橙（重点标注）[6](@ref)
    
    # 渐进强调色（数据分层）
    'gradient_1': '#4DB6AC',       # 碧绿色（第一层级）[3](@ref)
    'gradient_2': '#88CCEE',       # 天空蓝（第二层级）[6](@ref)
    'gradient_3': '#F08080',       # 粉红色（第三层级）[1](@ref)
    
    # 特殊场景色
    'negative': '#90EE90',         # 浅绿（负值/损失）[6](@ref)
    'positive': '#FFB6C1',         # 浅粉（正值/增益）[3](@ref)
    'warning': '#FF6B35',          # 火橙（警告提示）[5](@ref)
    'info': '#88C0D0'              # 冰蓝色（辅助信息）[5](@ref)
}

# %%
import matplotlib.pyplot as plt
import numpy as np

# 绘制ETTh2数据
fig, axs = plt.subplots(1, 4, figsize=(10, 2.5))


for j in range(4):
    ax = axs[j]  # 获取当前子图
    if j == 0:
        ax.plot(ETTh2_24_true_data_normalized_g[0:50, 0], label='True Value', color=colors_academic['primary'])
        ax.plot(ETTh2_24_pred_data_normalized_g[0:50, 0], label='MLP', color=colors_academic['accent'])
        ax.plot(ETTh2_24_pred_data_normalized_i[0:50, 0], label='Interpreter', color=colors_academic['secondary'])
    elif j == 1:
        ax.plot(ETTh2_24_enc_out_data_normalized_i[0:50, 0], label='Interpreter - E', color=colors_academic['gradient_3'])
        ax.plot(ETTh2_24_true_data_normalized_i[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 2:
        ax.plot(ETTh2_residual_i[0:50, 0], label='Residual', color=colors_academic['highlight'])
        ax.plot(ETTh2_24_true_data_normalized_i[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 3:
        ax.plot(ETTh2_24_enc_out_data_normalized_g[0:50, 0], label='MLP - E', color=colors_academic['warning'])
        ax.plot(ETTh2_24_true_data_normalized_g[0:50, 0], label='True', color=colors_academic['primary'])
    ax.legend(loc='upper right', fontsize=10)
    ax.grid(True) 


plt.tight_layout()
plt.savefig('ETTh2.svg')

plt.show()

# %%
#绘制TRC数据
fig, axs = plt.subplots(1, 4, figsize=(10, 2.5))
for j in range(4):
    ax = axs[j]  # 获取当前子图
    if j == 0:
        ax.plot(TRC_24_true_data_normalized_g[0:50, 0], label='True Value', color=colors_academic['primary'])
        ax.plot(TRC_24_pred_data_normalized_g[0:50, 0], label='MLP', color=colors_academic['accent'])
        ax.plot(TRC_24_pred_data_normalized_i[0:50, 0], label='Interpreter', color=colors_academic['secondary'])
    elif j == 1:
        ax.plot(TRC_24_enc_out_data_normalized_i[0:50, 0], label='Interpreter - E', color=colors_academic['gradient_3'])
        ax.plot(TRC_24_true_data_normalized_i[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 2:
        ax.plot(TRC_residual_i[0:50, 0], label='Residual', color=colors_academic['highlight'])
        ax.plot(TRC_24_true_data_normalized_i[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 3:
        ax.plot(TRC_24_enc_out_data_normalized_g[0:50, 0], label='MLP - E', color=colors_academic['warning'])
        ax.plot(TRC_24_true_data_normalized_g[0:50, 0], label='True', color=colors_academic['primary'])
    ax.legend(loc='upper right', fontsize=10)
    ax.grid(True)
plt.tight_layout()
plt.savefig('TRC.svg')
plt.show()

# %%
#绘制ECL数据
fig, axs = plt.subplots(1, 4, figsize=(10, 2.5))
for j in range(4):
    ax = axs[j]  # 获取当前子图
    if j == 0:
        ax.plot(ECL_24_true_data_normalized_g[0:50, 0], label='True Value', color=colors_academic['primary'])
        ax.plot(ECL_24_pred_data_normalized_g[0:50, 0], label='MLP', color=colors_academic['accent'])
        ax.plot(ECL_24_pred_data_normalized_i[0:50, 0], label='Interpreter', color=colors_academic['secondary'])
    elif j == 1:
        ax.plot(ECL_24_enc_out_data_normalized_i[0:50, 0], label='Interpreter - E', color=colors_academic['gradient_3'])
        ax.plot(ECL_24_true_data_normalized_g[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 2:
        ax.plot(ECL_residual_i[0:50, 0], label='Residual', color=colors_academic['highlight'])
        ax.plot(ECL_24_true_data_normalized_g[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 3:
        ax.plot(ECL_24_enc_out_data_normalized_g[0:50, 0], label='MLP - E', color=colors_academic['warning'])
        ax.plot(ECL_24_true_data_normalized_g[0:50, 0], label='True', color=colors_academic['primary'])
    ax.legend(loc='upper right', fontsize=10)
    ax.grid(True)
plt.tight_layout()
plt.savefig('ECL.svg')
plt.show()

# %%
#绘制WTH数据
fig, axs = plt.subplots(1, 4, figsize=(10, 2.5))
for j in range(4):
    ax = axs[j]  # 获取当前子图
    if j == 0:
        ax.plot(WTH_24_true_data_normalized_g[0:50, 0], label='True Value', color=colors_academic['primary'])
        ax.plot(WTH_24_pred_data_normalized_g[0:50, 0], label='MLP', color=colors_academic['accent'])
        ax.plot(WTH_24_pred_data_normalized_i[0:50, 0], label='Interpreter', color=colors_academic['secondary'])
    elif j == 1:
        ax.plot(WTH_24_enc_out_data_normalized_i[0:50, 0], label='Interpreter - E', color=colors_academic['gradient_3'])
        ax.plot(WTH_24_true_data_normalized_i[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 2:
        ax.plot(WTH_residual_i[0:50, 0], label='Residual', color=colors_academic['highlight'])
        ax.plot(WTH_24_true_data_normalized_i[0:50, 0], label='True', color=colors_academic['primary'])
    elif j == 3:
        ax.plot(WTH_24_enc_out_data_normalized_g[0:50, 0], label='MLP - E', color=colors_academic['warning'])
        ax.plot(WTH_24_true_data_normalized_g[0:50, 0], label='True', color=colors_academic['primary'])
    #ax.set_title(f'Subplot {1},{j+1}')
    ax.legend(loc='lower right', fontsize=10)
    ax.grid(True)
plt.tight_layout()
plt.savefig('WTH.svg')
plt.show()
